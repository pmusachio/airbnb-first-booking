# %% [markdown]
# # Airbnb Predict First Booking - Feature Engineering
#
# Comparison between raw data and the features prepared for modeling.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from airbnb_first_booking.config import load_config
from airbnb_first_booking.data import load_training_frame, profile_dataframe
from airbnb_first_booking.features import prepare_features

config = load_config()
config["project"]

# %%
df = load_training_frame(config)
features = prepare_features(df.copy(), config)
print('raw shape:', df.shape)
print('feature shape:', features.shape)
features.head()

# %%
new_columns = sorted(set(features.columns) - set(df.columns))
new_columns[:50], len(new_columns)

# %% [markdown]
# ## Feature rationale
#
# - Normalization of dates, age, gender and acquisition channels.
# - Scikit-learn pipeline handling numeric and categorical variables.
# - Evaluation with classification metrics and a focus on top-N ranking (NDCG@5).
